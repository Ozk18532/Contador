# %% [markdown]
# <a href="https://colab.research.google.com/github/Ozk18532/Contador/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Ozk18532/INTELIGENCIA-COMPUTACIONAL-Oscar-Mercado
# Out:
# Cloning into 'INTELIGENCIA-COMPUTACIONAL-Oscar-Mercado'...
# remote: Enumerating objects: 72, done.
# remote: Counting objects: 100% (72/72), done.
# remote: Compressing objects: 100% (66/66), done.
# remote: Total 72 (delta 25), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (72/72), 2.70 MiB | 13.55 MiB/s, done.
# Resolving deltas: 100% (25/25), done.

# %%
# %cd INTELIGENCIA-COMPUTACIONAL-Oscar-Mercado
# Out:
# /content/INTELIGENCIA-COMPUTACIONAL-Oscar-Mercado

# %%
# !ls
# Out:
#  2_evaluation_Oscar_Merrcado.ipynb
#  4_learning_curves_Oscar-Mercado.ipynb
# '5_cnn-Oscar Mercado.ipynb'
#  5_cnn_OscarM.ipynb
#  6_augmentation_Oscar_M.ipynb
#  App_del_sueño_V_01.ipynb
#  California_Housing_con_PyTorch.ipynb
#  California__Oscar_M.ipynb
#  EDA_y_preprocesamiento_Oscar_Mercado.ipynb
#  Gradio_App.ipynb
#  ML.ipynb
#  models
#  README.md
#  Redes_Neuronales_con_MNIST_Oscar__Mercado.ipynb
#  requirements.txt
#  streamlit_app.py

# %%
# !jupyter notebook 5_cnn_OscarM.ipynb
# Out:
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# [I 18:35:07.171 NotebookApp] Writing notebook server cookie secret to /root/.local/share/jupyter/runtime/notebook_cookie_secret
#
#   _   _          _      _
#  | | | |_ __  __| |__ _| |_ ___
#  | |_| | '_ \/ _` / _` |  _/ -_)
#   \___/| .__/\__,_\__,_|\__\___|
#        |_|
#
# Read the migration plan to Notebook 7 to learn about the new features and the actions to take if you are using extensions.
#
# https://jupyter-notebook.readthedocs.io/en/latest/migrate_to_notebook7.html
#
# Please note that updating to Notebook 7 might break some of your extensions.
#
# [I 18:35:07.489 NotebookApp] Loading IPython parallel extension
# [I 18:35:07.678 NotebookApp] [Jupytext Server Extension] Deriving a TextFileContentsManager from LargeFileManager
# [C 18:35:08.777 NotebookApp] Running as root is not recommended. Use --allow-root to bypass.
